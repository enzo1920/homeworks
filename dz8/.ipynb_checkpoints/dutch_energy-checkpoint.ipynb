# %% [markdown]
# ## details of the applications on Google Play

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.simplefilter('ignore')

# %matplotlib inline

#графики в svg выглядят более четкими
#%config InlineBackend.figure_format = 'svg' 
#sns.set(style="darkgrid")

#увеличим дефолтный размер графиков
from pylab import rcParams
rcParams['figure.figsize'] =15, 9
import pandas as pd

# %% [markdown]
# ## Импорт данных

# %%
# Импортируем данные  stat  inpit
#https://www.kaggle.com/lava18/google-play-store-apps
app_data = pd.read_csv("googleplaystore.csv")
app_data.columns = ["app", "category", "raiting", "reviews", "size", "installs","type","price","content_raiting","geners","last_updated","current_ver","android_ver"]
#app_data['datestamp'] =  pd.to_datetime(app_data['last_updated'])
#app_data['size_in_MB']=app_data.size.replace['M',"",inplace=True]
#app_data.size.replace("M", "", inplace=True)
app_data.raiting.fillna(0, inplace=True)
#app_data.type_of_connection.fillna(0, inplace=True)

# %%
app_data.sort_values("reviews", ascending=False).head(15)
# Out:
#                                                      app          category  \
# 2989                              GollerCepte Live Score            SPORTS
# 4970                        Ad Block REMOVER - NEED ROOT             TOOLS
# 2723                                 SnipSnap Coupon App          SHOPPING
# 2705                                 SnipSnap Coupon App          SHOPPING
# 3079                   US Open Tennis Championships 2018            SPORTS
# 3229                                          DreamTrips  TRAVEL_AND_LOCAL
# 3049                   US Open Tennis Championships 2018            SPORTS
# 7002    Adult Color by Number Book - Paint Mandala Pages            FAMILY
# 6724                      BSPlayer ARMv7 VFP CPU support     VIDEO_PLAYERS
# 7982   Easy Resume Builder, Resume help, Curriculum v...             TOOLS
# 353                                    MegaFon Dashboard     COMMUNICATION
# ...

# %% [markdown]
# ## Количество установок приложений для транспортных средств в зависимости от версии Android

# %%
g = sns.countplot(
    x="android_ver", hue="installs",
    data=app_data[app_data.geners=="Auto & Vehicles"]
)

# %% [markdown]
# ## Топ-10 в категории "коммуникации" отсортированных по установкам

# %%
app_data[app_data.category=="COMMUNICATION"].sort_values("installs", ascending=False).head(10)
# Out:
#                                               app       category  raiting  \
# 4039        Google Duo - High Quality Video Calls  COMMUNICATION      4.6
# 4122                  LINE: Free Calls & Messages  COMMUNICATION      4.2
# 431                               Viber Messenger  COMMUNICATION      4.3
# 3971  UC Browser - Fast Download Private & Secure  COMMUNICATION      4.5
# 378   UC Browser - Fast Download Private & Secure  COMMUNICATION      4.5
# 383                 imo free video calls and chat  COMMUNICATION      4.3
# 420   UC Browser - Fast Download Private & Secure  COMMUNICATION      4.5
# 347                 imo free video calls and chat  COMMUNICATION      4.3
# 474                   LINE: Free Calls & Messages  COMMUNICATION      4.2
# 4222                imo free video calls and chat  COMMUNICATION      4.3
#
#        reviews                size      installs  type price content_raiting  \
# ...

# %% [markdown]
# ## Топ-20 приложений для автомобилей отсортированных по рейтингу, установленных на  Android 4.0.3.

# %%
app_data[(app_data.category=="Auto & Vehicles") & (app_data.android_ver=="4.0.3 and up")].sort_values("raiting", ascending=False).head(20)
# Out:
#                                                     app           category  \
# 70    Fines of the State Traffic Safety Inspectorate...  AUTO_AND_VEHICLES
# 60                                         CityBus Lviv  AUTO_AND_VEHICLES
# 92                              Fuelio: Gas log & costs  AUTO_AND_VEHICLES
# 93                                           auto fines  AUTO_AND_VEHICLES
# 94    Used car is the first car - used car purchase,...  AUTO_AND_VEHICLES
# 96                 Inquiry Fines and Debits of Vehicles  AUTO_AND_VEHICLES
# 83        Speed Camera Detector - Traffic & Speed Alert  AUTO_AND_VEHICLES
# 49                          Monster Truck Stunt 3D 2019  AUTO_AND_VEHICLES
# 69                          Used cars for sale - Trovit  AUTO_AND_VEHICLES
# 91                                              SKencar  AUTO_AND_VEHICLES
# 87                        RST - Sale of cars on the PCT  AUTO_AND_VEHICLES
# ...

# %%
app_data.sort_values("installs", ascending=False).head(10)
# Out:
#                                                app            category  \
# 10472      Life Made WI-Fi Touchscreen Photo Frame                 1.9
# 420    UC Browser - Fast Download Private & Secure       COMMUNICATION
# 474                    LINE: Free Calls & Messages       COMMUNICATION
# 3767                  Flipboard: News For Our Time  NEWS_AND_MAGAZINES
# 3574                                   Cloud Print        PRODUCTIVITY
# 3326                  Gboard - the Google Keyboard               TOOLS
# 431                                Viber Messenger       COMMUNICATION
# 4222                 imo free video calls and chat       COMMUNICATION
# 3235                              Google Translate               TOOLS
# 1842                              Candy Crush Saga                GAME
#
#        raiting   reviews                size      installs  type     price  \
# 10472     19.0      3.0M              1,000+          Free     0  Everyone
# ...

# %%
top_10_yearly = {}
    tmp_df = app_data[app_data.app_data=="reviews"]
    top_10_yearly[year] = {
        "median": tmp_df.sort_values("income", ascending=False).income[:100].median(),
        "mean": tmp_df.sort_values("income", ascending=False).income[:100].mean()
    }

top_10_yearly = pd.DataFrame.from_dict(top_10_yearly, orient="columns").T
sns.lineplot(data=top_10_yearly)
